# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# /Users/jklymak/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:878: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
np.power(-31.,1./3.)
# Out:
# /Users/jklymak/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in power
#   if __name__ == '__main__':
# nan

# %%
u0s = np.logspace(-2,2,100)
h0 = 1.
g = 1.
fig,ax = plt.subplots()
u0 = u0s
#for H in [-16,-8,-4,-2,-1,1,2,4,8,16]:
for H in [4]:
    u1 = 0.*u0s
    
    B0 = 0.5*u0**2+g*(h0+H)
    d = (g*h0*u0)**2 - 8*(B0**3)/27.+0.*1j
    u1 = (-g*h0*u0+np.sqrt(d))**(1./3.)+(-g*h0*u0-np.sqrt(d))**(1./3.)

    print u1
    ax.loglog(u0s,u1)
# Out:
# <img src="data:image/png;base64,...">
# [   3.16129301    3.16119865    3.16109542    3.16098254    3.16085914
#     3.1607243     3.16057702    3.16041623    3.1602408     3.1600495
#     3.15984104    3.15961406    3.15936711    3.1590987     3.15880727
#     3.15849122    3.15814894    3.15777879    3.1573792     3.15694867
#     3.15648582    3.15598949    3.15545881    3.15489332    3.15429313
#     3.15365906    3.15299288    3.1522976     3.15157779    3.15084001
#     3.15009328    3.1493498     3.14862563    3.1479417     3.14732493
#     3.14680966    3.14643938    3.14626882    3.14636649    3.14681778
#     3.1477287     3.14923039    3.15148457    3.15469001    3.15909033
#     3.16498315    3.17273091    3.1827734     3.19564218    3.21197673
#     3.23254242    3.2582495     3.29017276    3.32957045    3.377901
#     3.43683585    3.50826615    3.59430204    3.69726342    3.8196631
#     3.96418464    4.1336589     4.33104433    4.55941594    4.82196642
# ...

# %%
-np.power(0.4,1./3.)
# Out:
# -0.73680629972807732
